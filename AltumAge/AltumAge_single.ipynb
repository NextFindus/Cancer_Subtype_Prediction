41169', 'E-GEOD-32149', 'E-GEOD-41826', 'E-GEOD-42700', 'E-GEOD-32146', 'E-GEOD-30870', 'E-GEOD-34639', 'E-GEOD-63347', 'E-GEOD-59592', 'GSE27317', 'GSE41037', 'GSE38873', 'GSE15745', 'GSE25892', 'GSE20242', 'GSE22595', 'GSE17448', 'GSE36642', 'GSE34035', 'GSE28746', 'GSE20236', 'GSE19711', 'GSE37008', 'GSE36812', 'GSE34257', 'GSE38608', 'GSE38291', 'GSE36166', 'GSE59274', 'GSE57285', 'GSE56606', 'GSE49908', 'GSE49907', 'GSE49905', 'GSE49904', 'GSE90124', 'GSE115797', 'GSE99624', 'GSE108213', 'GSE92767', 'GSE69176', 'GSE40360', 'GSE42861', 'GSE77241', 'GSE148000', 'TGCA_LUSC', 'TGCA_THCA', 'TGCA_HNSC', 'TGCA_KIRC', 'TGCA_KIRP', 'TGCA_LUAD', 'TGCA_PRAD', 'TGCA_STAD', 'TGCA_COAD', 'TGCA_LIHC', 'TGCA_UCEC', 'TGCA_BRCA']

# %% [markdown]
# # Model

# %%
import math
import os
import random
import gc

import numpy as np
import pandas as pd
import matplotlib

from sklearn.impute import SimpleImputer
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, GridSearchCV, PredefinedSplit

from IPython.display import clear_output

from pytorch_tabnet.tab_model import TabNetClassifier, TabNetRegressor

import tensorflow as tf
print(tf.__version__)  # should print 2.19.0

import tensorflow.compat.v1 as tf_v1
estimator = __import__("tensorflow_estimator.python.estimator.api._v1.estimator", fromlist=['estimator'])
import neural_structured_learning as nsl

import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots


from tensorflow.keras import regularizers, datasets, layers, models
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (Activation, InputLayer, ActivityRegularization, GaussianDropout, GaussianNoise,
                                     Embedding, Bidirectional, Input, LSTM, GRU, multiply, Lambda, PReLU, SimpleRNN,
                                     Dense, BatchNormalization, Conv2D, Conv1D, Flatten, LeakyReLU, Dropout,
                                     MaxPooling2D, MaxPooling1D, Reshape)
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import GridSearchCV, PredefinedSplit
from scikeras.wrappers import KerasRegressor

from my_functions import *    # use carefully only if necessary
import pickle
import tensorrt
# Out:
# 2025-08-14 16:58:29.374097: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-08-14 16:58:29.374131: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-08-14 16:58:29.375298: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-08-14 16:58:29.380817: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-08-14 16:58:30.856080: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2.15.0

# %%
random.seed(1)
tf.random.set_seed(1)
np.random.seed(1)

# %%
random.seed(1)
random.shuffle(all_data)

# %%
#load CpG site arrays
epic_cpgs = np.array(pd.read_csv('/sybig/home/fim/Dokumente/Sysbio/AltumAgeNew/AltumAgeModels/epic_cpgs.txt', header = None, sep = '\t')[0])
gs_cpgs = np.array(pd.read_csv('/sybig/home/fim/Dokumente/Sysbio/AltumAgeNew/AltumAgeModels/gold_standard.csv').Name)
multi_platform_cpgs = np.intersect1d(epic_cpgs, gs_cpgs)

# %% [markdown]
# ## Model Selection and Validation

# %%
#load all train data for model training and validation


dir_path = f"/sybig/home/fim/Dokumente/Sysbio/AltumAgeNew/data_by_tissue/{tissue_type}"

pkl_files = [f for f in os.listdir(dir_path) if f.endswith("_train.pkl")]

data_list = []
count=0

for file in pkl_files:
    count+=1
    file_path = os.path.join(dir_path, file)
    with open(file_path, 'rb') as f:
        data = pd.read_pickle(f)
        data_list.append(data)

concatenated = pd.concat(data_list, ignore_index=True)

print(f'count files: {count}')

train, validation = train_test_split(concatenated, test_size=0.2)

print(train.head)
# Out:
# count files: 8
# <bound method NDFrame.head of           dataset                     tissue_type   age gender  cg00000292  \
# 164  E-GEOD-41826            brain frontal cortex  36.0      F    0.581582
# 33       GSE49905           brain cerebral cortex   5.0      F    0.722359
# 95   E-GEOD-76105  brain superior temporal gyrus   79.0      F    0.648076
# 124  E-GEOD-61107            brain frontal cortex  74.0      M    0.701292
# 58       GSE49905           brain cerebral cortex  20.0      M    0.655938
# ..            ...                             ...   ...    ...         ...
# 133  E-GEOD-61107            brain frontal cortex  75.0      M    0.648968
# 137  E-GEOD-41826            brain frontal cortex  42.0      F    0.604214
# 72       GSE38873                      cerebellum  50.0    NaN    0.518963
# 140  E-GEOD-41826            brain frontal cortex  26.0      F    0.804575
# 37       GSE49905           brain cerebral cortex   9.0      M    0.285092
#
#      cg00002426  cg00003994  cg00005847  cg00007981  cg00008493  ...  \
# 164    0.347492    0.097620    0.252484    0.013472    0.915173  ...
# 33     0.253406    0.028294    0.179617    0.039731    0.981073  ...
# 95     0.430186    0.109033    0.172711    0.013612    0.925761  ...
# 124    0.314804    0.084629    0.132092    0.022392    0.927699  ...
# 58     0.202516    0.052728    0.159942    0.050787    0.979759  ...
# ..          ...         ...         ...         ...         ...  ...
# 133    0.395536    0.073877    0.145510    0.022024    0.918647  ...
# 137    0.353052    0.085275    0.211044    0.010110    0.886878  ...
# 72     0.080876    0.073475    0.111626    0.041667    0.970188  ...
# 140    0.338263    0.042090    0.155955    0.014314    0.843045  ...
# 37     0.336655    0.213104    0.255823    0.068681    0.979139  ...
#
#      cg27650175  cg27650434  cg27652350  cg27653134  cg27654142  cg27655905  \
# 164    0.041769    0.202603    0.181833    0.789596    0.078781    0.057918
# 33     0.014214    0.116943    0.186982    0.719338    0.030428    0.074829
# 95     0.030259    0.208651    0.259071    0.766640    0.053730    0.035368
# 124    0.045563    0.119862    0.214398    0.794521    0.046838    0.070082
# 58     0.016886    0.124867    0.135169    0.673179    0.030907    0.073468
# ..          ...         ...         ...         ...         ...         ...
# 133    0.050994    0.120310    0.247756    0.797139    0.064275    0.055395
# 137    0.036983    0.219049    0.189485    0.733960    0.059437    0.059991
# 72     0.018034    0.069799    0.695940    0.815899    0.037024    0.077157
# 140    0.045853    0.117862    0.315429    0.827546    0.060878    0.041762
# 37     0.012103    0.125656    0.200682    0.362594    0.022122    0.058087
#
#      cg27657283  cg27662379  cg27662877  cg27665659
# 164    0.030272    0.043769    0.019935    0.095910
# 33     0.058132    0.012296    0.034000    0.058257
# 95     0.021195    0.032919    0.024260    0.113902
# 124    0.048718    0.054108    0.044513    0.072492
# 58     0.125111    0.014640    0.029795    0.069560
# ..          ...         ...         ...         ...
# 133    0.043158    0.064713    0.037836    0.072242
# 137    0.036903    0.046242    0.033212    0.118677
# 72     0.049165    0.014836    0.037627    0.031215
# 140    0.037443    0.063812    0.029939    0.041728
# 37     0.232135    0.019120    0.070979    0.025409
#
# [152 rows x 21372 columns]>

# %%
#extracting age and removing unimportant columns
train_ages = train['age'].astype('float64')
val_ages = validation['age'].astype('float64')

train_info = train[['dataset', 'tissue_type', 'age', 'gender']]
validation_info = validation[['dataset', 'tissue_type', 'age', 'gender']]

train = train.drop(columns = ['dataset', 'tissue_type', 'age', 'gender'], axis=0)
validation = validation.drop(columns = ['dataset', 'tissue_type', 'age', 'gender'], axis=0)


print(train.head)
# Out:
# <bound method NDFrame.head of      cg00000292  cg00002426  cg00003994  cg00005847  cg00007981  cg00008493  \
# 164    0.581582    0.347492    0.097620    0.252484    0.013472    0.915173
# 33     0.722359    0.253406    0.028294    0.179617    0.039731    0.981073
# 95     0.648076    0.430186    0.109033    0.172711    0.013612    0.925761
# 124    0.701292    0.314804    0.084629    0.132092    0.022392    0.927699
# 58     0.655938    0.202516    0.052728    0.159942    0.050787    0.979759
# ..          ...         ...         ...         ...         ...         ...
# 133    0.648968    0.395536    0.073877    0.145510    0.022024    0.918647
# 137    0.604214    0.353052    0.085275    0.211044    0.010110    0.886878
# 72     0.518963    0.080876    0.073475    0.111626    0.041667    0.970188
# 140    0.804575    0.338263    0.042090    0.155955    0.014314    0.843045
# 37     0.285092    0.336655    0.213104    0.255823    0.068681    0.979139
#
#      cg00008713  cg00009407  cg00011459  cg00012199  ...  cg27650175  \
# 164    0.087491    0.033626    0.891890    0.037533  ...    0.041769
# 33     0.040622    0.025586    0.730485    0.029049  ...    0.014214
# 95     0.061694    0.049401    0.837795    0.033654  ...    0.030259
# 124    0.076633    0.041731    0.904866    0.051929  ...    0.045563
# 58     0.034884    0.018056    0.751949    0.023776  ...    0.016886
# ..          ...         ...         ...         ...  ...         ...
# 133    0.076392    0.038193    0.859889    0.059652  ...    0.050994
# 137    0.078267    0.030968    0.895515    0.057997  ...    0.036983
# 72     0.047191    0.079377    0.907161    0.031698  ...    0.018034
# 140    0.089753    0.037477    0.818143    0.050958  ...    0.045853
# 37     0.035172    0.021108    0.508874    0.024330  ...    0.012103
#
#      cg27650434  cg27652350  cg27653134  cg27654142  cg27655905  cg27657283  \
# 164    0.202603    0.181833    0.789596    0.078781    0.057918    0.030272
# 33     0.116943    0.186982    0.719338    0.030428    0.074829    0.058132
# 95     0.208651    0.259071    0.766640    0.053730    0.035368    0.021195
# 124    0.119862    0.214398    0.794521    0.046838    0.070082    0.048718
# 58     0.124867    0.135169    0.673179    0.030907    0.073468    0.125111
# ..          ...         ...         ...         ...         ...         ...
# 133    0.120310    0.247756    0.797139    0.064275    0.055395    0.043158
# 137    0.219049    0.189485    0.733960    0.059437    0.059991    0.036903
# 72     0.069799    0.695940    0.815899    0.037024    0.077157    0.049165
# 140    0.117862    0.315429    0.827546    0.060878    0.041762    0.037443
# 37     0.125656    0.200682    0.362594    0.022122    0.058087    0.232135
#
#      cg27662379  cg27662877  cg27665659
# 164    0.043769    0.019935    0.095910
# 33     0.012296    0.034000    0.058257
# 95     0.032919    0.024260    0.113902
# 124    0.054108    0.044513    0.072492
# 58     0.014640    0.029795    0.069560
# ..          ...         ...         ...
# 133    0.064713    0.037836    0.072242
# 137    0.046242    0.033212    0.118677
# 72     0.014836    0.037627    0.031215
# 140    0.063812    0.029939    0.041728
# 37     0.019120    0.070979    0.025409
#
# [152 rows x 21368 columns]>

# %%
#save names of columns and indexes
train_cols = train.columns
train_index = train.index

validation_cols = validation.columns
validation_index = validation.index

# %%
#scaling the data so each columns has 0 mean and variance 1
###is this nesserary here??????

scaler = preprocessing.RobustScaler()

train_scaled = pd.DataFrame(scaler.fit_transform(train), index = train_index, columns = train_cols)
validation_scaled = pd.DataFrame(scaler.transform(validation), index = validation_index, columns = validation_cols)


train = train[multi_platform_cpgs]
validation = validation[multi_platform_cpgs]
train_scaled = train_scaled[multi_platform_cpgs]
validation_scaled = validation_scaled[multi_platform_cpgs]

# %% [markdown]
# ## AltumAge

# %%
#neural network architecture
coeff = 0.05 * np.sqrt(2.0 * np.log(train_scaled.shape[1]) / train_scaled.shape[0]) 
noise = 0.1
input_shape = train_scaled.shape[1]
initializer = tf.keras.initializers.LecunNormal(seed=1)
nn_model = Sequential([
    Input(shape=(input_shape,), name = 'feature'),
    BatchNormalization(),
    GaussianDropout(noise),
    ActivityRegularization(0, coeff*10),
    Dense(32, kernel_initializer = initializer, kernel_regularizer=tf.keras.regularizers.l1_l2(0, coeff*2)),
    Activation('selu'),
    BatchNormalization(),
    GaussianDropout(noise),
    ActivityRegularization(0, 0),
    Dense(32, kernel_initializer = initializer, kernel_regularizer=tf.keras.regularizers.l1_l2(0, coeff*2)),
    Activation('selu'),
    BatchNormalization(),
    GaussianDropout(noise),
    ActivityRegularization(0, 0),
    Dense(32, kernel_initializer = initializer, kernel_regularizer=tf.keras.regularizers.l1_l2(0, coeff*2)),
    Activation('selu'),
    BatchNormalization(),
    GaussianDropout(noise),
    ActivityRegularization(0, 0),
    Dense(32, kernel_initializer = initializer, kernel_regularizer=tf.keras.regularizers.l1_l2(0, coeff*2)),
    Activation('selu'),
    BatchNormalization(),
    GaussianDropout(noise),
    ActivityRegularization(0, 0),
    Dense(32, kernel_initializer = initializer, kernel_regularizer=tf.keras.regularizers.l1_l2(0, coeff*2)),
    Activation('selu'),
    BatchNormalization(),
    Dense(1)
])

# %%
print("Train scaled shape:", train_scaled.shape)
# Out:
# Train scaled shape: (152, 20318)

# %%
checkpoint_filepath = '/tmp/checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='loss',
    mode='min',
    save_best_only=True)

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.2,
                              patience=30, min_lr=0.00001)

adv_config = nsl.configs.make_adv_reg_config(multiplier=0.05, adv_step_size=0.005)

#adv_config = nsl.configs.make_adv_reg_config(multiplier=0.01, adv_step_size=0.001)

adv_model = nsl.keras.AdversarialRegularization(nn_model, adv_config=adv_config)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.002, beta_1=0.9, beta_2=0.999, epsilon=1e-07)

# Compile, train, and evaluate.
adv_model.compile(optimizer=optimizer,
                  loss='mse',
                  metrics=['mae'])


train_ds = tf.data.Dataset.from_tensor_slices(
    ({'feature': train_scaled.astype('float32'), 'label': train_ages.astype('float32')},)
).batch(256)

val_ds = tf.data.Dataset.from_tensor_slices(
    ({'feature': validation_scaled.astype('float32'), 'label': val_ages.astype('float32')},)
).batch(256)


history = adv_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=100,
    callbacks=[model_checkpoint_callback, reduce_lr]
)
adv_model.load_weights(checkpoint_filepath)
# Out:
# Epoch 1/100
# WARNING:absl:Cannot perturb features dict_keys(['label'])
# 1/1 [==============================] - 6s 6s/step - loss: 10732.4570 - mean_squared_error: 2471.3936 - mean_absolute_error: 44.0114 - scaled_adversarial_loss: 123.5666 - val_loss: 9637.5283 - val_mean_squared_error: 2937.0771 - val_mean_absolute_error: 48.6034 - val_scaled_adversarial_loss: 146.8638 - lr: 0.0020
# Epoch 2/100
# 1/1 [==============================] - 0s 189ms/step - loss: 10705.9062 - mean_squared_error: 2469.9839 - mean_absolute_error: 43.9968 - scaled_adversarial_loss: 123.5005 - val_loss: 9476.4668 - val_mean_squared_error: 2895.1455 - val_mean_absolute_error: 48.2379 - val_scaled_adversarial_loss: 144.7632 - lr: 0.0020
# Epoch 3/100
# 1/1 [==============================] - 0s 184ms/step - loss: 10675.2295 - mean_squared_error: 2468.4963 - mean_absolute_error: 43.9822 - scaled_adversarial_loss: 123.4259 - val_loss: 9328.4258 - val_mean_squared_error: 2838.2808 - val_mean_absolute_error: 47.6777 - val_scaled_adversarial_loss: 141.9176 - lr: 0.0020
# Epoch 4/100
# 1/1 [==============================] - 0s 182ms/step - loss: 10645.8242 - mean_squared_error: 2467.1702 - mean_absolute_error: 43.9680 - scaled_adversarial_loss: 123.3574 - val_loss: 9208.7412 - val_mean_squared_error: 2793.0808 - val_mean_absolute_error: 47.2068 - val_scaled_adversarial_loss: 139.6566 - lr: 0.0020
# 1/1 [==============================] - 0s 177ms/step - loss: 9146.7559 - mean_squared_error: 2377.5974 - mean_absolute_error: 42.9510 - scaled_adversarial_loss: 118.8797 - val_loss: 8134.0254 - val_mean_squared_error: 2653.5051 - val_mean_absolute_error: 45.7144 - val_scaled_adversarial_loss: 132.6755 - lr: 0.0020
# Epoch 51/100
# 1/1 [==============================] - 0s 167ms/step - loss: 9111.2236 - mean_squared_error: 2374.7444 - mean_absolute_error: 42.9182 - scaled_adversarial_loss: 118.7371 - val_loss: 8119.4414 - val_mean_squared_error: 2650.2925 - val_mean_absolute_error: 45.6793 - val_scaled_adversarial_loss: 132.5148 - lr: 0.0020
# Epoch 52/100
# 1/1 [==============================] - 0s 191ms/step - loss: 9074.6299 - mean_squared_error: 2371.8445 - mean_absolute_error: 42.8848 - scaled_adversarial_loss: 118.5920 - val_loss: 8104.2891 - val_mean_squared_error: 2646.5562 - val_mean_absolute_error: 45.6384 - val_scaled_adversarial_loss: 132.3280 - lr: 0.0020
# Epoch 53/100
# 1/1 [==============================] - 0s 164ms/step - loss: 9056.3154 - mean_squared_error: 2368.9080 - mean_absolute_error: 42.8509 - scaled_adversarial_loss: 118.4453 - val_loss: 8089.3047 - val_mean_squared_error: 2643.0032 - val_mean_absolute_error: 45.5994 - val_scaled_adversarial_loss: 132.1503 - lr: 0.0020
# Epoch 54/100
# 1/1 [==============================] - 0s 226ms/step - loss: 9025.7100 - mean_squared_error: 2365.9109 - mean_absolute_error: 42.8165 - scaled_adversarial_loss: 118.2958 - val_loss: 8074.5273 - val_mean_squared_error: 2639.6802 - val_mean_absolute_error: 45.5630 - val_scaled_adversarial_loss: 131.9842 - lr: 0.0020
# Epoch 55/100
# 1/1 [==============================] - 0s 186ms/step - loss: 8994.4053 - mean_squared_error: 2362.8740 - mean_absolute_error: 42.7815 - scaled_adversarial_loss: 118.1437 - val_loss: 8059.6260 - val_mean_squared_error: 2636.2729 - val_mean_absolute_error: 45.5256 - val_scaled_adversarial_loss: 131.8138 - lr: 0.0020
# Epoch 56/100
# 1/1 [==============================] - 0s 175ms/step - loss: 8958.5283 - mean_squared_error: 2359.7898 - mean_absolute_error: 42.7460 - scaled_adversarial_loss: 117.9894 - val_loss: 8044.7241 - val_mean_squared_error: 2632.8994 - val_mean_absolute_error: 45.4885 - val_scaled_adversarial_loss: 131.6452 - lr: 0.0020
# Epoch 57/100
# 1/1 [==============================] - 0s 184ms/step - loss: 8928.5645 - mean_squared_error: 2356.6907 - mean_absolute_error: 42.7099 - scaled_adversarial_loss: 117.8334 - val_loss: 8030.0698 - val_mean_squared_error: 2629.8113 - val_mean_absolute_error: 45.4545 - val_scaled_adversarial_loss: 131.4907 - lr: 0.0020
# Epoch 58/100
# 1/1 [==============================] - 0s 170ms/step - loss: 8897.2471 - mean_squared_error: 2353.5000 - mean_absolute_error: 42.6732 - scaled_adversarial_loss: 117.6753 - val_loss: 8015.9829 - val_mean_squared_error: 2627.3120 - val_mean_absolute_error: 45.4271 - val_scaled_adversarial_loss: 131.3658 - lr: 0.0020
# Epoch 59/100
# 1/1 [==============================] - 0s 159ms/step - loss: 8863.9941 - mean_squared_error: 2350.2910 - mean_absolute_error: 42.6361 - scaled_adversarial_loss: 117.5148 - val_loss: 8001.6597 - val_mean_squared_error: 2624.6416 - val_mean_absolute_error: 45.3977 - val_scaled_adversarial_loss: 131.2322 - lr: 0.0020
# Epoch 60/100
# 1/1 [==============================] - 0s 180ms/step - loss: 8832.7441 - mean_squared_error: 2347.0344 - mean_absolute_error: 42.5983 - scaled_adversarial_loss: 117.3515 - val_loss: 7987.2476 - val_mean_squared_error: 2621.9319 - val_mean_absolute_error: 45.3678 - val_scaled_adversarial_loss: 131.0968 - lr: 0.0020
# Epoch 61/100
# 1/1 [==============================] - 0s 243ms/step - loss: 8804.5137 - mean_squared_error: 2343.7253 - mean_absolute_error: 42.5600 - scaled_adversarial_loss: 117.1860 - val_loss: 7972.2368 - val_mean_squared_error: 2618.7161 - val_mean_absolute_error: 45.3323 - val_scaled_adversarial_loss: 130.9360 - lr: 0.0020
# Epoch 62/100
# 1/1 [==============================] - 0s 190ms/step - loss: 8772.6553 - mean_squared_error: 2340.3999 - mean_absolute_error: 42.5211 - scaled_adversarial_loss: 117.0186 - val_loss: 7954.3862 - val_mean_squared_error: 2612.8545 - val_mean_absolute_error: 45.2676 - val_scaled_adversarial_loss: 130.6429 - lr: 0.0020
# Epoch 63/100
# 1/1 [==============================] - 0s 173ms/step - loss: 8741.0342 - mean_squared_error: 2336.9812 - mean_absolute_error: 42.4817 - scaled_adversarial_loss: 116.8492 - val_loss: 7936.8530 - val_mean_squared_error: 2607.3628 - val_mean_absolute_error: 45.2069 - val_scaled_adversarial_loss: 130.3683 - lr: 0.0020
# Epoch 64/100
# 1/1 [==============================] - 0s 163ms/step - loss: 8709.2285 - mean_squared_error: 2333.5493 - mean_absolute_error: 42.4417 - scaled_adversarial_loss: 116.6775 - val_loss: 7920.8950 - val_mean_squared_error: 2603.4402 - val_mean_absolute_error: 45.1635 - val_scaled_adversarial_loss: 130.1721 - lr: 0.0020
# Epoch 65/100
# 1/1 [==============================] - 0s 163ms/step - loss: 8677.3164 - mean_squared_error: 2330.0513 - mean_absolute_error: 42.4011 - scaled_adversarial_loss: 116.5024 - val_loss: 7905.9360 - val_mean_squared_error: 2600.5354 - val_mean_absolute_error: 45.1314 - val_scaled_adversarial_loss: 130.0269 - lr: 0.0020
# Epoch 66/100
# 1/1 [==============================] - 0s 173ms/step - loss: 8653.6396 - mean_squared_error: 2326.5200 - mean_absolute_error: 42.3600 - scaled_adversarial_loss: 116.3260 - val_loss: 7890.7910 - val_mean_squared_error: 2597.5374 - val_mean_absolute_error: 45.0981 - val_scaled_adversarial_loss: 129.8770 - lr: 0.0020
# Epoch 67/100
# 1/1 [==============================] - 0s 172ms/step - loss: 8621.0391 - mean_squared_error: 2322.9490 - mean_absolute_error: 42.3184 - scaled_adversarial_loss: 116.1480 - val_loss: 7874.3154 - val_mean_squared_error: 2593.3489 - val_mean_absolute_error: 45.0517 - val_scaled_adversarial_loss: 129.6676 - lr: 0.0020
# Epoch 68/100
# 1/1 [==============================] - 0s 176ms/step - loss: 8587.1182 - mean_squared_error: 2319.3191 - mean_absolute_error: 42.2761 - scaled_adversarial_loss: 115.9662 - val_loss: 7856.9648 - val_mean_squared_error: 2588.4102 - val_mean_absolute_error: 44.9968 - val_scaled_adversarial_loss: 129.4206 - lr: 0.0020
# Epoch 69/100
# 1/1 [==============================] - 0s 167ms/step - loss: 8552.8623 - mean_squared_error: 2315.6646 - mean_absolute_error: 42.2334 - scaled_adversarial_loss: 115.7828 - val_loss: 7838.7852 - val_mean_squared_error: 2582.7527 - val_mean_absolute_error: 44.9339 - val_scaled_adversarial_loss: 129.1378 - lr: 0.0020
# Epoch 70/100
# 1/1 [==============================] - 0s 178ms/step - loss: 8528.7451 - mean_squared_error: 2311.9609 - mean_absolute_error: 42.1901 - scaled_adversarial_loss: 115.5977 - val_loss: 7821.6719 - val_mean_squared_error: 2578.1934 - val_mean_absolute_error: 44.8831 - val_scaled_adversarial_loss: 128.9098 - lr: 0.0020
# Epoch 71/100
# 1/1 [==============================] - 0s 165ms/step - loss: 8493.8438 - mean_squared_error: 2308.1821 - mean_absolute_error: 42.1461 - scaled_adversarial_loss: 115.4095 - val_loss: 7804.5269 - val_mean_squared_error: 2573.6748 - val_mean_absolute_error: 44.8328 - val_scaled_adversarial_loss: 128.6839 - lr: 0.0020
# Epoch 72/100
# 1/1 [==============================] - 0s 169ms/step - loss: 8467.1924 - mean_squared_error: 2304.3887 - mean_absolute_error: 42.1018 - scaled_adversarial_loss: 115.2205 - val_loss: 7786.4580 - val_mean_squared_error: 2568.3469 - val_mean_absolute_error: 44.7733 - val_scaled_adversarial_loss: 128.4175 - lr: 0.0020
# Epoch 73/100
# 1/1 [==============================] - 0s 174ms/step - loss: 8436.4375 - mean_squared_error: 2300.5291 - mean_absolute_error: 42.0567 - scaled_adversarial_loss: 115.0266 - val_loss: 7768.1123 - val_mean_squared_error: 2562.8416 - val_mean_absolute_error: 44.7118 - val_scaled_adversarial_loss: 128.1422 - lr: 0.0020
# Epoch 74/100
# 1/1 [==============================] - 0s 165ms/step - loss: 8401.8613 - mean_squared_error: 2296.6399 - mean_absolute_error: 42.0114 - scaled_adversarial_loss: 114.8321 - val_loss: 7749.6787 - val_mean_squared_error: 2557.3376 - val_mean_absolute_error: 44.6502 - val_scaled_adversarial_loss: 127.8670 - lr: 0.0020
# Epoch 75/100
# 1/1 [==============================] - 0s 170ms/step - loss: 8375.4990 - mean_squared_error: 2292.7073 - mean_absolute_error: 41.9655 - scaled_adversarial_loss: 114.6350 - val_loss: 7731.1934 - val_mean_squared_error: 2551.8713 - val_mean_absolute_error: 44.5890 - val_scaled_adversarial_loss: 127.5937 - lr: 0.0020
# Epoch 76/100
# 1/1 [==============================] - 0s 183ms/step - loss: 8341.2734 - mean_squared_error: 2288.7134 - mean_absolute_error: 41.9189 - scaled_adversarial_loss: 114.4362 - val_loss: 7712.6865 - val_mean_squared_error: 2546.4536 - val_mean_absolute_error: 44.5282 - val_scaled_adversarial_loss: 127.3228 - lr: 0.0020
# Epoch 77/100
# 1/1 [==============================] - 0s 167ms/step - loss: 8316.3193 - mean_squared_error: 2284.6970 - mean_absolute_error: 41.8720 - scaled_adversarial_loss: 114.2350 - val_loss: 7695.1836 - val_mean_squared_error: 2542.0818 - val_mean_absolute_error: 44.4791 - val_scaled_adversarial_loss: 127.1042 - lr: 0.0020
# Epoch 78/100
# 1/1 [==============================] - 0s 163ms/step - loss: 8280.0391 - mean_squared_error: 2280.6313 - mean_absolute_error: 41.8245 - scaled_adversarial_loss: 114.0316 - val_loss: 7679.1592 - val_mean_squared_error: 2539.2004 - val_mean_absolute_error: 44.4467 - val_scaled_adversarial_loss: 126.9601 - lr: 0.0020
# Epoch 79/100
# 1/1 [==============================] - 0s 165ms/step - loss: 8252.2441 - mean_squared_error: 2276.4963 - mean_absolute_error: 41.7764 - scaled_adversarial_loss: 113.8260 - val_loss: 7662.0889 - val_mean_squared_error: 2535.4072 - val_mean_absolute_error: 44.4039 - val_scaled_adversarial_loss: 126.7704 - lr: 0.0020
# Epoch 80/100
# 1/1 [==============================] - 0s 163ms/step - loss: 8229.5381 - mean_squared_error: 2272.3853 - mean_absolute_error: 41.7280 - scaled_adversarial_loss: 113.6196 - val_loss: 7642.9595 - val_mean_squared_error: 2529.7407 - val_mean_absolute_error: 44.3401 - val_scaled_adversarial_loss: 126.4871 - lr: 0.0020
# Epoch 81/100
# 1/1 [==============================] - 0s 164ms/step - loss: 8188.5669 - mean_squared_error: 2268.1265 - mean_absolute_error: 41.6786 - scaled_adversarial_loss: 113.4071 - val_loss: 7623.0430 - val_mean_squared_error: 2523.4060 - val_mean_absolute_error: 44.2686 - val_scaled_adversarial_loss: 126.1704 - lr: 0.0020
# Epoch 82/100
# 1/1 [==============================] - 0s 165ms/step - loss: 8162.2583 - mean_squared_error: 2263.9199 - mean_absolute_error: 41.6289 - scaled_adversarial_loss: 113.1958 - val_loss: 7603.4775 - val_mean_squared_error: 2517.4905 - val_mean_absolute_error: 44.2017 - val_scaled_adversarial_loss: 125.8746 - lr: 0.0020
# Epoch 83/100
# 1/1 [==============================] - 0s 162ms/step - loss: 8128.3291 - mean_squared_error: 2259.6047 - mean_absolute_error: 41.5786 - scaled_adversarial_loss: 112.9799 - val_loss: 7584.8247 - val_mean_squared_error: 2512.5161 - val_mean_absolute_error: 44.1455 - val_scaled_adversarial_loss: 125.6259 - lr: 0.0020
# Epoch 84/100
# 1/1 [==============================] - 0s 165ms/step - loss: 8103.8701 - mean_squared_error: 2255.2881 - mean_absolute_error: 41.5277 - scaled_adversarial_loss: 112.7642 - val_loss: 7565.4819 - val_mean_squared_error: 2506.9827 - val_mean_absolute_error: 44.0827 - val_scaled_adversarial_loss: 125.3492 - lr: 0.0020
# Epoch 85/100
# 1/1 [==============================] - 0s 230ms/step - loss: 8076.8291 - mean_squared_error: 2250.8774 - mean_absolute_error: 41.4762 - scaled_adversarial_loss: 112.5447 - val_loss: 7546.4385 - val_mean_squared_error: 2501.8120 - val_mean_absolute_error: 44.0240 - val_scaled_adversarial_loss: 125.0907 - lr: 0.0020
# Epoch 86/100
# 1/1 [==============================] - 0s 165ms/step - loss: 8044.6045 - mean_squared_error: 2246.4453 - mean_absolute_error: 41.4241 - scaled_adversarial_loss: 112.3229 - val_loss: 7527.4858 - val_mean_squared_error: 2496.8066 - val_mean_absolute_error: 43.9672 - val_scaled_adversarial_loss: 124.8404 - lr: 0.0020
# Epoch 87/100
# 1/1 [==============================] - 0s 167ms/step - loss: 8015.3223 - mean_squared_error: 2241.9568 - mean_absolute_error: 41.3715 - scaled_adversarial_loss: 112.0980 - val_loss: 7507.4956 - val_mean_squared_error: 2490.8923 - val_mean_absolute_error: 43.8999 - val_scaled_adversarial_loss: 124.5447 - lr: 0.0020
# Epoch 88/100
# 1/1 [==============================] - 0s 172ms/step - loss: 7982.3696 - mean_squared_error: 2237.4529 - mean_absolute_error: 41.3182 - scaled_adversarial_loss: 111.8727 - val_loss: 7487.7573 - val_mean_squared_error: 2485.3015 - val_mean_absolute_error: 43.8362 - val_scaled_adversarial_loss: 124.2652 - lr: 0.0020
# Epoch 89/100
# 1/1 [==============================] - 0s 164ms/step - loss: 7949.0171 - mean_squared_error: 2232.8792 - mean_absolute_error: 41.2644 - scaled_adversarial_loss: 111.6442 - val_loss: 7467.5693 - val_mean_squared_error: 2479.3464 - val_mean_absolute_error: 43.7682 - val_scaled_adversarial_loss: 123.9674 - lr: 0.0020
# Epoch 90/100
# 1/1 [==============================] - 0s 168ms/step - loss: 7914.6738 - mean_squared_error: 2228.2910 - mean_absolute_error: 41.2101 - scaled_adversarial_loss: 111.4140 - val_loss: 7446.7876 - val_mean_squared_error: 2472.9019 - val_mean_absolute_error: 43.6945 - val_scaled_adversarial_loss: 123.6452 - lr: 0.0020
# Epoch 91/100
# 1/1 [==============================] - 0s 176ms/step - loss: 7892.1812 - mean_squared_error: 2223.6475 - mean_absolute_error: 41.1551 - scaled_adversarial_loss: 111.1826 - val_loss: 7426.2197 - val_mean_squared_error: 2466.7371 - val_mean_absolute_error: 43.6239 - val_scaled_adversarial_loss: 123.3369 - lr: 0.0020
# Epoch 92/100
# 1/1 [==============================] - 0s 163ms/step - loss: 7867.6138 - mean_squared_error: 2218.9836 - mean_absolute_error: 41.0995 - scaled_adversarial_loss: 110.9487 - val_loss: 7407.8818 - val_mean_squared_error: 2462.7751 - val_mean_absolute_error: 43.5784 - val_scaled_adversarial_loss: 123.1389 - lr: 0.0020
# Epoch 93/100
# 1/1 [==============================] - 0s 162ms/step - loss: 7838.8652 - mean_squared_error: 2214.2231 - mean_absolute_error: 41.0434 - scaled_adversarial_loss: 110.7112 - val_loss: 7389.1060 - val_mean_squared_error: 2458.4656 - val_mean_absolute_error: 43.5290 - val_scaled_adversarial_loss: 122.9234 - lr: 0.0020
# Epoch 94/100
# 1/1 [==============================] - 0s 226ms/step - loss: 7804.7148 - mean_squared_error: 2209.4548 - mean_absolute_error: 40.9867 - scaled_adversarial_loss: 110.4724 - val_loss: 7370.5283 - val_mean_squared_error: 2454.4236 - val_mean_absolute_error: 43.4825 - val_scaled_adversarial_loss: 122.7213 - lr: 0.0020
# Epoch 95/100
# 1/1 [==============================] - 0s 247ms/step - loss: 7776.7158 - mean_squared_error: 2204.6697 - mean_absolute_error: 40.9294 - scaled_adversarial_loss: 110.2323 - val_loss: 7350.6357 - val_mean_squared_error: 2449.2012 - val_mean_absolute_error: 43.4225 - val_scaled_adversarial_loss: 122.4601 - lr: 0.0020
# Epoch 96/100
# 1/1 [==============================] - 0s 174ms/step - loss: 7744.0625 - mean_squared_error: 2199.7976 - mean_absolute_error: 40.8715 - scaled_adversarial_loss: 109.9897 - val_loss: 7330.6904 - val_mean_squared_error: 2444.0000 - val_mean_absolute_error: 43.3625 - val_scaled_adversarial_loss: 122.2001 - lr: 0.0020
# Epoch 97/100
# 1/1 [==============================] - 0s 174ms/step - loss: 7714.2148 - mean_squared_error: 2194.8894 - mean_absolute_error: 40.8131 - scaled_adversarial_loss: 109.7447 - val_loss: 7310.5117 - val_mean_squared_error: 2438.6399 - val_mean_absolute_error: 43.3007 - val_scaled_adversarial_loss: 121.9321 - lr: 0.0020
# Epoch 98/100
# 1/1 [==============================] - 0s 174ms/step - loss: 7682.3574 - mean_squared_error: 2189.9478 - mean_absolute_error: 40.7541 - scaled_adversarial_loss: 109.4987 - val_loss: 7288.1787 - val_mean_squared_error: 2431.2949 - val_mean_absolute_error: 43.2158 - val_scaled_adversarial_loss: 121.5648 - lr: 0.0020
# Epoch 99/100
# 1/1 [==============================] - 0s 170ms/step - loss: 7656.8892 - mean_squared_error: 2184.9658 - mean_absolute_error: 40.6944 - scaled_adversarial_loss: 109.2483 - val_loss: 7265.3115 - val_mean_squared_error: 2423.5056 - val_mean_absolute_error: 43.1255 - val_scaled_adversarial_loss: 121.1754 - lr: 0.0020
# Epoch 100/100
# 1/1 [==============================] - 0s 171ms/step - loss: 7623.0938 - mean_squared_error: 2179.9368 - mean_absolute_error: 40.6342 - scaled_adversarial_loss: 108.9977 - val_loss: 7242.7925 - val_mean_squared_error: 2416.1084 - val_mean_absolute_error: 43.0397 - val_scaled_adversarial_loss: 120.8055 - lr: 0.0020

# %%
#using model to predict validation data
pred_ages = adv_model.base_model.predict(validation_scaled).flatten()
pred_ages = pd.Series(pred_ages, index = validation_index, name = 'pred_age')

nn_results = pd.concat([validation_info, pred_ages], axis=1, sort=False, join='inner')
# Out:
# 2/2 [==============================] - 0s 3ms/step

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'mean_squared_error', 'mean_absolute_error', 'scaled_adversarial_loss', 'val_loss', 'val_mean_squared_error', 'val_mean_absolute_error', 'val_scaled_adversarial_loss', 'lr'])

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'loss')
plotter.plot({'nn':history})

# %%
#using model to predict validation data
pred_ages = adv_model.base_model.predict(validation_scaled).flatten()
pred_ages = pd.Series(pred_ages, index = validation_index, name = 'pred_age')

nn_results = pd.concat([validation_info, pred_ages], axis=1, sort=False, join='inner')
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %%
#quick view of metrics: #with BN right before Dense(1) and Activity Reg in all layers 0.1 noise position changed 0.001 lr
mae = np.median(np.abs(pred_ages - val_ages))
mse = np.mean((pred_ages - val_ages)**2)
print('MAE: '+ str(mae))
print('MSE: '+ str(mse))
# Out:
# MAE: 43.28108501434326
# MSE: 2414.8006774785704

# %%
#saving results
nn_results.to_pickle(f'/sybig/home/fim/Dokumente/Sysbio/AltumAgeNew/AltumAgeModels/altumage_{tissue_type}.pkl')

# %% [markdown]
# ### _________________________________________________________________________________________________________

# %% [markdown]
# ## Training with full train and Testing

# %%
full_train = pd.concat([train, validation], axis=0)
full_train_scaled = pd.concat([train_scaled, validation_scaled], axis=0)
full_train_ages = pd.concat([train_ages, val_ages], axis=0)

full_train_info = pd.concat([train_info, validation_info], axis=0)
full_train_index = full_train_info.index

# %%
# Assuming your test data is stored in the same structure but named "*_test.pkl"
test_pkl_files = [f for f in os.listdir(dir_path) if f.endswith("_test.pkl")]

test_data_list = []
test_count = 0

for file in test_pkl_files:
    test_count += 1
    file_path = os.path.join(dir_path, file)
    with open(file_path, 'rb') as f:
        data = pd.read_pickle(f)
        test_data_list.append(data)

# Combine all test data into one DataFrame
test_all = pd.concat(test_data_list, ignore_index=True)
print(f'count test files: {test_count}')

# Extract ages and meta info
test_ages = test_all['age'].astype('float64')
test_info = test_all[['dataset', 'tissue_type', 'age', 'gender']]

# Drop unneeded columns
test = test_all.drop(columns=['dataset', 'tissue_type', 'age', 'gender'], axis=0)

# IMPORTANT: use the *same* scaler fitted on train set
test_scaled = pd.DataFrame(
    scaler.transform(test), index=test.index, columns=test.columns
)

# Apply same column filtering
test = test[multi_platform_cpgs]
test_scaled = test_scaled[multi_platform_cpgs]
test_index=test.index
# Out:
# count test files: 8

# %%
#neural network architecture
coeff = 0.05 * np.sqrt(2.0 * np.log(train_scaled.shape[1]) / train_scaled.shape[0]) 
noise = 0.1
initializer = tf.keras.initializers.LecunNormal(seed=1)
nn_model = Sequential([
    Input(shape=(20318,), name = 'feature'),
    BatchNormalization(),
    GaussianDropout(noise),
    ActivityRegularization(0, coeff*10),
    Dense(32, kernel_initializer = initializer, kernel_regularizer=tf.keras.regularizers.l1_l2(0, coeff*2)),
    Activation('selu'),
    BatchNormalization(),
    GaussianDropout(noise),
    ActivityRegularization(0, 0),
    Dense(32, kernel_initializer = initializer, kernel_regularizer=tf.keras.regularizers.l1_l2(0, coeff*2)),
    Activation('selu'),
    BatchNormalization(),
    GaussianDropout(noise),
    ActivityRegularization(0, 0),
    Dense(32, kernel_initializer = initializer, kernel_regularizer=tf.keras.regularizers.l1_l2(0, coeff*2)),
    Activation('selu'),
    BatchNormalization(),
    GaussianDropout(noise),
    ActivityRegularization(0, 0),
    Dense(32, kernel_initializer = initializer, kernel_regularizer=tf.keras.regularizers.l1_l2(0, coeff*2)),
    Activation('selu'),
    BatchNormalization(),
    GaussianDropout(noise),
    ActivityRegularization(0, 0),
    Dense(32, kernel_initializer = initializer, kernel_regularizer=tf.keras.regularizers.l1_l2(0, coeff*2)),
    Activation('selu'),
    BatchNormalization(),
    Dense(1)
])

# %%
checkpoint_filepath = '/tmp/checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='loss',
    mode='min',
    save_best_only=True)

# %%
random.seed(1)
tf.random.set_seed(1)
np.random.seed(1)

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.2,
                              patience=30, min_lr=0.00001)

adv_config = nsl.configs.make_adv_reg_config(multiplier=0.05, adv_step_size=0.005)
adv_model = nsl.keras.AdversarialRegularization(nn_model, adv_config=adv_config)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.002, beta_1=0.9, beta_2=0.999, epsilon=1e-07)

# Compile, train, and evaluate.
adv_model.compile(optimizer=optimizer,
                  loss='mse',
                  metrics=['mae'])

history = adv_model.fit(
    {'feature': np.array(full_train_scaled), 'label': np.array(full_train_ages)},
    batch_size=256,
    epochs=60,
    verbose=0,
    callbacks=[model_checkpoint_callback, reduce_lr]
)

adv_model.load_weights(checkpoint_filepath)

# %%
adv_model.base_model.save(f'AltumAge_npj_{tissue_type}.h5')
# Out:
# /sybig/home/fim/Dokumente/Sysbio/.venv/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
#using model to predict train and test data
pred_ages_train = adv_model.base_model.predict(train_scaled).flatten()
pred_ages_train = pd.Series(pred_ages_train, index = train_index, name = 'pred_age')

nn_results_train = pd.concat([train_info, pred_ages_train], axis=1, sort=False, join='inner')

pred_ages_test = adv_model.base_model.predict(test_scaled).flatten()
pred_ages_test = pd.Series(pred_ages_test, index = test_index, name = 'pred_age')

nn_results_test = pd.concat([test_info, pred_ages_test], axis=1, sort=False, join='inner')
# Out:
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 3ms/step

# %%
#quick view of metrics:
mae = np.median(np.abs(pred_ages_test - test_ages))
mse = np.mean((pred_ages_test - test_ages)**2)
print('MAE: '+ str(mae))
print('MSE: '+ str(mse))
# Out:
# MAE: 45.065160155296326
# MSE: 2466.8364006210936

# %%
#saving results
nn_results_train.to_csv(f'/sybig/home/fim/Dokumente/Sysbio/AltumAgeNew/Results/train/altum_age_{tissue_type}.csv')
nn_results_test.to_csv(f'/sybig/home/fim/Dokumente/Sysbio/AltumAgeNew/Results/test/altum_age_{tissue_type}.csv')
